# %% [markdown]
# Лабораторная работа 7.

# %%
import sys
sys.path.append('..')
# %matplotlib inline
import matplotlib.pyplot as plt
import cv2 as cv
import cv2 as cv2
import numpy as np

# %%
image2 = cv.imread('2.png')
image2 = cv.imread('1.png')

gray_query = cv.cvtColor(image2, cv.COLOR_BGR2GRAY)
gray_target = cv.cvtColor(image1, cv.COLOR_BGR2GRAY)

result = cv.matchTemplate(gray_target, gray_query, cv.TM_CCOEFF_NORMED)

min_val, max_val, min_loc, max_loc = cv.minMaxLoc(result)

top_left = max_loc
bottom_right = (top_left[0] + query_image.shape[1], top_left[1] + query_image.shape[0])
cv.rectangle(target_image, top_left, bottom_right, (0, 255, 0), 2)

image_rgb = cv.cvtColor(target_image, cv.COLOR_BGR2RGB)

plt.imshow(image_rgb)
plt.show()
